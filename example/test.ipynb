# %%
import sys

sys.path.append('../')
from const import *
from train import *

# %%
config = get_config()
train_dataset, val_dataset, predict_dataset = load_dataset(DATASET_WEEK_PATH)
train_dataloader, val_dataloader, predict_dataloader = get_dataloader(
    train_dataset, val_dataset, predict_dataset, config
)

# %%
batch = next(iter(train_dataloader))
for k, v in batch.items():
    print(k, v.shape, v.type())
# Out:
# past_time_features torch.Size([51963, 89, 23]) torch.FloatTensor
# past_values torch.Size([51963, 89]) torch.FloatTensor
# past_observed_mask torch.Size([51963, 89]) torch.FloatTensor
# future_time_features torch.Size([51963, 12, 23]) torch.FloatTensor
# static_real_features torch.Size([51963, 224]) torch.FloatTensor
# future_values torch.Size([51963, 12]) torch.FloatTensor
# future_observed_mask torch.Size([51963, 12]) torch.FloatTensor

# %%
from gluonts.time_feature import time_features_from_frequency_str

time_features = time_features_from_frequency_str("1W")

# %%
batch['past_time_features'].shape
# Out:
# torch.Size([51963, 53, 21])

# %%
batch['past_time_features'][0][4]
# Out:
# tensor([0.4771, 0.2856, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000])

# %%
train_dataset[0]['target']
# Out:
# [12.953140445331947,
#  7.392578214854432,
#  13.929487805230922,
#  10.583950921639657,
#  12.972154840613271,
#  0.0,
#  13.739822448816112,
#  14.26319004889503,
#  11.23695551685583,
#  0.0,
#  14.370563459701595,
#  14.087099223225529,
#  8.729044494134834,
#  0.0,
#  10.360720220805257,
#  11.176790564023063,
#  12.373716975076537,
#  10.614491300852881,
#  9.09778300045833,
#  0.0,
#  14.402624242016786,
#  7.208980210776484,
#  9.750766059268381,
#  0.0,
#  10.421450166819241,
#  7.314853736693084,
#  11.39404756747599,
#  7.399093943885144,
#  8.918798320318178,
#  0.0,
#  0.0,
#  12.105032250100228,
#  12.224678631891996,
#  11.356684490018353,
#  11.995142662264055,
#  12.023371260751327,
#  13.423724102247919,
#  12.636437903126396,
#  14.276701814529714,
#  11.145964115959202,
#  13.934799714059974,
#  11.890476137558135,
#  0.0,
#  10.988556640376851,
#  13.776554519625273,
#  10.290304534623724,
#  13.371397083306062,
#  10.34581609798352,
#  11.090265030920014,
#  12.089898107494024,
#  11.399903765350796,
#  9.58179222362466,
#  11.84222427044847,
#  0.0,
#  13.36697645564053,
#  9.463069575899617,
#  10.236253970098645,
#  14.441201650842176,
#  13.110660718872824,
#  13.222810438469699,
#  12.324524658760042,
#  12.114992603901626,
#  12.24626274669787,
#  0.0,
#  12.493396628973393,
#  13.952158188977885,
#  13.113140820887677,
#  5.993727228842128,
#  0.0,
#  12.214819584454846,
#  10.925425187766175,
#  12.558412086472316,
#  0.0,
#  14.972081165113924,
#  9.230379859431096,
#  0.0,
#  12.350846083744973,
#  0.0,
#  11.96054644321589,
#  9.540493034345866,
#  14.298071433353043,
#  0.0,
#  11.190407676198536,
#  10.876031504343366,
#  13.151568491498798,
#  9.963976043763685,
#  13.529218424048144,
#  11.85240124003937,
#  11.451396660089397,
#  11.41276260749322,
#  7.634782917245287,
#  12.904121896510409,
#  11.321931168219471,
#  9.807153235200694]

# %%
import numpy as np

# %%
np.emath.logn(1000, 100)
# Out:
# 0.6666666666666666
